# %% [markdown]
# # SpaGCN toy运行入口
# 该Notebook不复制官方完整教程，而是给出固定commit与安全入口。实际训练需要组织图像或显式选择histology=False。

# %%
OFFICIAL_COMMIT = 'dc7a1c26ea0fdf4dfe7064adc7699be141b4871f'
OFFICIAL_TUTORIAL = f'https://github.com/jianhuupenn/SpaGCN/blob/{OFFICIAL_COMMIT}/tutorial/tutorial.ipynb'
print(OFFICIAL_TUTORIAL)

# %% [markdown]
# 运行顺序：读取10x H5/positions → 写入AnnData坐标 → `calculate_adj_matrix` → `search_l`/`search_res` → `SpaGCN.train` → `predict` → 可选`refine` → SVG/meta-gene分析。请直接使用固定commit的官方Notebook，以免本仓库副本失去更新来源。
