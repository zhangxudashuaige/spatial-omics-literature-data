# %% [markdown]
# # 01 资源清单统计
# 读取五张CSV，检查四类资源是否被正确分开。

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
META = ROOT / 'metadata'
files = {
    '预训练语料': 'pretraining_corpora.csv',
    '下游数据': 'downstream_datasets.csv',
    '数据平台': 'data_platforms.csv',
    '模型仓库': 'model_repositories.csv',
    '模型—数据关系': 'task_model_matrix.csv',
}
tables = {name: pd.read_csv(META / file) for name, file in files.items()}
pd.DataFrame({'resource_type': tables.keys(), 'rows': [len(df) for df in tables.values()]})

# %%
tables['预训练语料'][['model', 'corpus_name', 'survey_reported_size', 'access_type']].head(15)
